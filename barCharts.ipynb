# %%
import matplotlib.pyplot as plt 
import numpy as np

# %%
linear_data = np.array([1,2,3,4,5,6,7,8])
xvals = range(len(linear_data))
plt.bar(xvals, linear_data, width=0.3)
# Out:
# <BarContainer object of 8 artists>

# %%
new_xvals=[]
exponential_data = linear_data ** 2

for item in xvals:
    new_xvals.append(item+0.3)
    
plt.bar(xvals, linear_data, width=0.3)    
plt.bar(new_xvals, exponential_data, width=0.3, color='red')
# Out:
# <BarContainer object of 8 artists>

# %%
from random import randint

linear_err = [randint(1,4) for x in range(len(linear_data))]
plt.bar(xvals, linear_data, width=0.3, yerr=linear_err)
# Out:
# <BarContainer object of 8 artists>

# %%
xvals = range(len(linear_data))
plt.bar(xvals, linear_data, width=0.3, color='b')
plt.bar(xvals, exponential_data, width=0.3, bottom=linear_data,color='b')
# Out:
# <BarContainer object of 8 artists>

# %%
xvals = range(len(linear_data))
plt.barh(xvals, linear_data, height=0.3, color='r')
plt.barh(xvals, exponential_data, height=0.3, left=linear_data,color='b')
# Out:
# <BarContainer object of 8 artists>
