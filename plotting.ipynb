# %%
import matplotlib as mpl 
mpl.get_backend()
# Out:
# 'module://matplotlib_inline.backend_inline'

# %%
import matplotlib.pyplot as plt 
plt.plot
# Out:
# <function matplotlib.pyplot.plot(*args: 'float | ArrayLike | str', scalex: 'bool' = True, scaley: 'bool' = True, data=None, **kwargs) -> 'list[Line2D]'>

# %%
plt.plot(3,2,'.')

# %%
from matplotlib.backends.backend_agg import FigureCanvasAgg
from matplotlib.figure import Figure

fig = Figure()
canvas = FigureCanvasAgg(fig)
ax = fig.add_subplot(111)
ax.plot(3,2,'.')
canvas.print_png('test.png')

# %%
# %%html
# <img src='test.png' />
# Out:
# <img src='test.png' />

# %%
plt.figure() 
plt.plot(3,2,'o')
ax = plt.gca()
ax.axis([0,6,0,10])
# Out:
# (np.float64(0.0), np.float64(6.0), np.float64(0.0), np.float64(10.0))

# %%
plt.figure()
plt.plot(1.5, 1.5, 'o')
plt.plot(2, 2, 'o')
plt.plot(2.5, 2.5, 'o')

# %%
ax = plt.gca()
plt.plot(1.5, 1.5, 'o')
ax.get_children()
# Out:
# [<matplotlib.lines.Line2D at 0x7f74f6dff310>,
#  <matplotlib.spines.Spine at 0x7f74f77c2200>,
#  <matplotlib.spines.Spine at 0x7f74f77c29e0>,
#  <matplotlib.spines.Spine at 0x7f74f77c23b0>,
#  <matplotlib.spines.Spine at 0x7f74f77c3bb0>,
#  <matplotlib.axis.XAxis at 0x7f74f77c2440>,
#  <matplotlib.axis.YAxis at 0x7f74f77c2a40>,
#  Text(0.5, 1.0, ''),
#  Text(0.0, 1.0, ''),
#  Text(1.0, 1.0, ''),
#  <matplotlib.patches.Rectangle at 0x7f74f6dfd150>]
