# %%
import matplotlib.pyplot as plt 
import numpy as np

# %%
languages = ['python', 'javascipt', 'c++', 'sql', 'java']
position = np.arange(len(languages))
popularity = [56, 45, 23, 67, 89]

plt.figure(figsize=(10,8))
plt.bar(position, popularity, align='center')
plt.xticks(position, languages)
plt.ylabel('% popularity')
plt.title('top 5 languages for math & data')
# Out:
# Text(0.5, 1.0, 'top 5 languages for math & data')

# %%
languages = ['python', 'javascipt', 'c++', 'sql', 'java']
position = np.arange(len(languages))
popularity = [56, 45, 23, 67, 89]

plt.figure(figsize=(10,8))
plt.bar(position, popularity, align='center')
plt.xticks(position, languages)
plt.ylabel('% popularity')
plt.title('top 5 languages for math & data')
# remove the frame of the chart
for spine in plt.gca().spines.values():
    spine.set_visible(False)

# %%
languages = ['python', 'javascipt', 'c++', 'sql', 'java']
position = np.arange(len(languages))
popularity = [56, 45, 23, 67, 89]

plt.figure(figsize=(10,8))
bars = plt.bar(position, popularity, align='center', linewidth=0, color='lightslategrey')
bars[4].set_color('#1F7784')

plt.xticks(position, languages, alpha=0.8)
plt.title('top 5 languages for math & data', alpha=0.8)
# remove the frame of the chart
for spine in plt.gca().spines.values():
    spine.set_visible(False)
